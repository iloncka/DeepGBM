# %% [markdown]
# <a href="https://colab.research.google.com/github/iloncka/DeepGBM/blob/master/DeepGBM_wine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Installations

# %%
#@title
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#@title
# !pip install torch==1.2.0 torchvision==0.4.0 tensorboardx LightGBM==2.2.1 scikit-learn==0.19.2 category-encoders tqdm
# Out:
# Requirement already satisfied: torch==1.2.0 in /usr/local/lib/python3.7/dist-packages (1.2.0)
# Requirement already satisfied: torchvision==0.4.0 in /usr/local/lib/python3.7/dist-packages (0.4.0)
# Requirement already satisfied: tensorboardx in /usr/local/lib/python3.7/dist-packages (2.4.1)
# Requirement already satisfied: LightGBM==2.2.1 in /usr/local/lib/python3.7/dist-packages (2.2.1)
# Requirement already satisfied: scikit-learn==0.19.2 in /usr/local/lib/python3.7/dist-packages (0.19.2)
# Requirement already satisfied: category-encoders in /usr/local/lib/python3.7/dist-packages (1.3.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (4.62.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch==1.2.0) (1.19.5)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from torchvision==0.4.0) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from torchvision==0.4.0) (1.15.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from LightGBM==2.2.1) (1.4.1)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorboardx) (3.17.3)
# Requirement already satisfied: patsy>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from category-encoders) (0.5.2)
# Requirement already satisfied: pandas>=0.20.1 in /usr/local/lib/python3.7/dist-packages (from category-encoders) (1.1.5)
# Requirement already satisfied: statsmodels>=0.6.1 in /usr/local/lib/python3.7/dist-packages (from category-encoders) (0.10.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.20.1->category-encoders) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.20.1->category-encoders) (2018.9)

# %%
#@title
# !pip install jupyter_contrib_nbextensions
# Out:
# Requirement already satisfied: jupyter_contrib_nbextensions in /usr/local/lib/python3.7/dist-packages (0.5.1)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.7/dist-packages (from jupyter_contrib_nbextensions) (4.9.1)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.7/dist-packages (from jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: jupyter-latex-envs>=1.3.8 in /usr/local/lib/python3.7/dist-packages (from jupyter_contrib_nbextensions) (1.4.6)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from jupyter_contrib_nbextensions) (4.2.6)
# Requirement already satisfied: jupyter-nbextensions-configurator>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from jupyter_contrib_nbextensions) (0.4.1)
# Requirement already satisfied: nbconvert>=4.2 in /usr/local/lib/python3.7/dist-packages (from jupyter_contrib_nbextensions) (5.6.1)
# Requirement already satisfied: jupyter-highlight-selected-word>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: tornado in /usr/local/lib/python3.7/dist-packages (from jupyter_contrib_nbextensions) (5.1.1)
# Requirement already satisfied: notebook>=4.0 in /usr/local/lib/python3.7/dist-packages (from jupyter_contrib_nbextensions) (5.3.1)
# Requirement already satisfied: traitlets>=4.1 in /usr/local/lib/python3.7/dist-packages (from jupyter_contrib_nbextensions) (5.1.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from jupyter_contrib_nbextensions) (3.13)
# Requirement already satisfied: jupyter-contrib-core>=0.3.3 in /usr/local/lib/python3.7/dist-packages (from jupyter_contrib_nbextensions) (0.3.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from jupyter-contrib-core>=0.3.3->jupyter_contrib_nbextensions) (57.4.0)
# Requirement already satisfied: ipython in /usr/local/lib/python3.7/dist-packages (from jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (5.5.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (0.3)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (2.6.1)
# Requirement already satisfied: nbformat>=4.4 in /usr/local/lib/python3.7/dist-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (5.1.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (0.8.4)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/dist-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (4.1.0)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (0.5.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (1.5.0)
# Requirement already satisfied: jinja2>=2.4 in /usr/local/lib/python3.7/dist-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (2.11.3)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert>=4.2->jupyter_contrib_nbextensions) (0.7.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2>=2.4->nbconvert>=4.2->jupyter_contrib_nbextensions) (2.0.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.4->nbconvert>=4.2->jupyter_contrib_nbextensions) (2.6.0)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (1.8.0)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.7/dist-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (4.10.1)
# Requirement already satisfied: jupyter-client>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (5.3.5)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.0->jupyter_contrib_nbextensions) (0.12.1)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from jupyter-client>=5.2.0->notebook>=4.0->jupyter_contrib_nbextensions) (2.8.2)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.7/dist-packages (from jupyter-client>=5.2.0->notebook>=4.0->jupyter_contrib_nbextensions) (22.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.1->jupyter-client>=5.2.0->notebook>=4.0->jupyter_contrib_nbextensions) (1.15.0)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.7/dist-packages (from terminado>=0.8.1->notebook>=4.0->jupyter_contrib_nbextensions) (0.7.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert>=4.2->jupyter_contrib_nbextensions) (0.5.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert>=4.2->jupyter_contrib_nbextensions) (21.3)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.7.5)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (1.0.18)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.8.1)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (4.8.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (4.4.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython->jupyter-latex-envs>=1.3.8->jupyter_contrib_nbextensions) (0.2.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->bleach->nbconvert>=4.2->jupyter_contrib_nbextensions) (3.0.6)

# %%
#@title
# !jupyter contrib nbextension install --user
# Out:
# [I 18:54:54 InstallContribNbextensionsApp] jupyter contrib nbextension install --user
# [I 18:54:54 InstallContribNbextensionsApp] Installing jupyter_contrib_nbextensions nbextension files to jupyter data directory
# [I 18:54:54 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.7/dist-packages/jupyter_contrib_nbextensions/nbextensions/comment-uncomment -> comment-uncomment
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/comment-uncomment/icon.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/comment-uncomment/main.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/comment-uncomment/comment-uncomment.yaml
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/comment-uncomment/readme.md
# [I 18:54:54 InstallContribNbextensionsApp] - Validating: OK
# [I 18:54:54 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.7/dist-packages/jupyter_contrib_nbextensions/nbextensions/hinterland -> hinterland
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/hinterland/hinterland.yaml
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/hinterland/hinterland.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/hinterland/README.md
# [I 18:54:54 InstallContribNbextensionsApp] - Validating: OK
# [I 18:54:54 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.7/dist-packages/jupyter_contrib_nbextensions/nbextensions/livemdpreview -> livemdpreview
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/livemdpreview/livemdpreview.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/livemdpreview/livemdpreview.yml
# [I 18:54:54 InstallContribNbextensionsApp] - Validating: OK
# [I 18:54:54 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.7/dist-packages/jupyter_contrib_nbextensions/nbextensions/select_keymap -> select_keymap
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/select_keymap/main.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/select_keymap/README.md
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/select_keymap/select_keymap.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/select_keymap/select_keymap.yaml
# [I 18:54:54 InstallContribNbextensionsApp] - Validating: OK
# [I 18:54:54 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.7/dist-packages/jupyter_contrib_nbextensions/nbextensions/addbefore -> addbefore
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/addbefore/addbefore.yaml
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/addbefore/icon.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/addbefore/main.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/addbefore/readme.md
# [I 18:54:54 InstallContribNbextensionsApp] - Validating: OK
# [I 18:54:54 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.7/dist-packages/jupyter_contrib_nbextensions/nbextensions/collapsible_headings -> collapsible_headings
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/collapsible_headings/icon.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/collapsible_headings/main.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/collapsible_headings/screenshot.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/collapsible_headings/collapsible_headings.yaml
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/collapsible_headings/main.css
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/collapsible_headings/readme.md
# [I 18:54:54 InstallContribNbextensionsApp] - Validating: OK
# [I 18:54:54 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.7/dist-packages/jupyter_contrib_nbextensions/nbextensions/navigation-hotkeys -> navigation-hotkeys
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/navigation-hotkeys/hotkeys.yaml
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/navigation-hotkeys/icon.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/navigation-hotkeys/main.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/navigation-hotkeys/readme.md
# [I 18:54:54 InstallContribNbextensionsApp] - Validating: OK
# [I 18:54:54 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.7/dist-packages/jupyter_contrib_nbextensions/nbextensions/limit_output -> limit_output
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/limit_output/icon.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/limit_output/limit-output.yaml
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/limit_output/main.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/limit_output/readme.md
# [I 18:54:54 InstallContribNbextensionsApp] - Validating: OK
# [I 18:54:54 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.7/dist-packages/jupyter_contrib_nbextensions/nbextensions/zenmode -> zenmode
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/zenmode/zenmode.yaml
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/zenmode/main.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/zenmode/README.md
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/zenmode/main.css
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/zenmode/images/back11.jpg
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/zenmode/images/back3.jpg
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/zenmode/images/back21.jpg
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/zenmode/images/back22.jpg
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/zenmode/images/back12.jpg
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/zenmode/images/ipynblogo0.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/zenmode/images/back2.jpg
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/zenmode/images/back1.jpg
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/zenmode/images/ipynblogo1.png
# [I 18:54:54 InstallContribNbextensionsApp] - Validating: OK
# [I 18:54:54 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.7/dist-packages/jupyter_contrib_nbextensions/nbextensions/table_beautifier -> table_beautifier
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/table_beautifier/main.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/table_beautifier/README.md
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/table_beautifier/table_beautifier.yaml
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/table_beautifier/main.css
# [I 18:54:54 InstallContribNbextensionsApp] - Validating: OK
# [I 18:54:54 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.7/dist-packages/jupyter_contrib_nbextensions/nbextensions/codefolding -> codefolding
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/codefolding/codefolding_editor.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/codefolding/codefolding_firstline_folded.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/codefolding/magic-folded.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/codefolding/edit.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/codefolding/icon.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/codefolding/codefolding_indent_unfolded.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/codefolding/foldgutter.css
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/codefolding/main.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/codefolding/codefolding_firstline_unfolded.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/codefolding/codefolding.yaml
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/codefolding/magic-unfolded.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/codefolding/codefolding_editor.yaml
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/codefolding/firstline-fold.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/codefolding/codefolding_indent_folded_1.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/codefolding/magic-fold.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/codefolding/readme.md
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/codefolding/codefolding_indent_folded_2.png
# [I 18:54:54 InstallContribNbextensionsApp] - Validating: OK
# [I 18:54:54 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.7/dist-packages/jupyter_contrib_nbextensions/nbextensions/codefolding -> codefolding
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/codefolding/codefolding_editor.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/codefolding/codefolding_firstline_folded.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/codefolding/magic-folded.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/codefolding/edit.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/codefolding/icon.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/codefolding/codefolding_indent_unfolded.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/codefolding/foldgutter.css
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/codefolding/main.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/codefolding/codefolding_firstline_unfolded.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/codefolding/codefolding.yaml
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/codefolding/magic-unfolded.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/codefolding/codefolding_editor.yaml
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/codefolding/firstline-fold.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/codefolding/codefolding_indent_folded_1.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/codefolding/magic-fold.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/codefolding/readme.md
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/codefolding/codefolding_indent_folded_2.png
# [I 18:54:54 InstallContribNbextensionsApp] - Validating: OK
# [I 18:54:54 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.7/dist-packages/jupyter_contrib_nbextensions/nbextensions/help_panel -> help_panel
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/help_panel/help_panel_ext_fullscreen.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/help_panel/icon.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/help_panel/help_panel.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/help_panel/help_panel.yaml
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/help_panel/help_panel.css
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/help_panel/readme.md
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/help_panel/help_panel_ext.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/help_panel/img/handle-v.png
# [I 18:54:54 InstallContribNbextensionsApp] - Validating: OK
# [I 18:54:54 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.7/dist-packages/jupyter_contrib_nbextensions/nbextensions/toggle_all_line_numbers -> toggle_all_line_numbers
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/toggle_all_line_numbers/icon.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/toggle_all_line_numbers/main.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/toggle_all_line_numbers/main.yaml
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/toggle_all_line_numbers/readme.md
# [I 18:54:54 InstallContribNbextensionsApp] - Validating: OK
# [I 18:54:54 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.7/dist-packages/jupyter_contrib_nbextensions/nbextensions/ruler -> ruler
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/ruler/edit.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/ruler/icon.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/ruler/ruler_editor.yaml
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/ruler/main.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/ruler/ruler.yaml
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/ruler/readme.md
# [I 18:54:54 InstallContribNbextensionsApp] - Validating: OK
# [I 18:54:54 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.7/dist-packages/jupyter_contrib_nbextensions/nbextensions/ruler -> ruler
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/ruler/edit.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/ruler/icon.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/ruler/ruler_editor.yaml
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/ruler/main.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/ruler/ruler.yaml
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/ruler/readme.md
# [I 18:54:54 InstallContribNbextensionsApp] - Validating: OK
# [I 18:54:54 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.7/dist-packages/jupyter_contrib_nbextensions/nbextensions/qtconsole -> qtconsole
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/qtconsole/README.md
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/qtconsole/qtconsole.yaml
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/qtconsole/qtconsole.js
# [I 18:54:54 InstallContribNbextensionsApp] - Validating: OK
# [I 18:54:54 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.7/dist-packages/jupyter_contrib_nbextensions/nbextensions/exercise2 -> exercise2
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/exercise2/image.gif
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/exercise2/icon.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/exercise2/main.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/exercise2/main.css
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/exercise2/readme.md
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/exercise2/exercise2.yaml
# [I 18:54:54 InstallContribNbextensionsApp] - Validating: OK
# [I 18:54:54 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.7/dist-packages/jupyter_contrib_nbextensions/nbextensions/spellchecker -> spellchecker
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/spellchecker/config.yaml
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/spellchecker/download_new_dict.py
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/spellchecker/main.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/spellchecker/README.md
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/spellchecker/screenshot.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/spellchecker/main.css
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/spellchecker/__pycache__/download_new_dict.cpython-37.pyc
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/spellchecker/typo/LICENSE.txt
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/spellchecker/typo/typo.js
# [I 18:54:54 InstallContribNbextensionsApp] - Validating: OK
# [I 18:54:54 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.7/dist-packages/jupyter_contrib_nbextensions/nbextensions/code_prettify -> code_prettify
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/demo-jv.gif
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/README_2to3.md
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/autopep8.yaml
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/kernel_exec_on_cell.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/isort.yaml
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/autopep8.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/demo_2to3.gif
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/README.md
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/README_code_prettify.md
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/demo-py.gif
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/2to3.yaml
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/code_prettify.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/code_prettify.yaml
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/demo-R.gif
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/2to3.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/isort.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/README_isort.md
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/README_autopep8.md
# [I 18:54:54 InstallContribNbextensionsApp] - Validating: OK
# [I 18:54:54 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.7/dist-packages/jupyter_contrib_nbextensions/nbextensions/code_prettify -> code_prettify
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/demo-jv.gif
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/README_2to3.md
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/autopep8.yaml
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/kernel_exec_on_cell.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/isort.yaml
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/autopep8.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/demo_2to3.gif
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/README.md
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/README_code_prettify.md
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/demo-py.gif
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/2to3.yaml
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/code_prettify.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/code_prettify.yaml
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/demo-R.gif
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/2to3.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/isort.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/README_isort.md
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/README_autopep8.md
# [I 18:54:54 InstallContribNbextensionsApp] - Validating: OK
# [I 18:54:54 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.7/dist-packages/jupyter_contrib_nbextensions/nbextensions/code_prettify -> code_prettify
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/demo-jv.gif
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/README_2to3.md
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/autopep8.yaml
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/kernel_exec_on_cell.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/isort.yaml
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/autopep8.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/demo_2to3.gif
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/README.md
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/README_code_prettify.md
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/demo-py.gif
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/2to3.yaml
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/code_prettify.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/code_prettify.yaml
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/demo-R.gif
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/2to3.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/isort.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/README_isort.md
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/README_autopep8.md
# [I 18:54:54 InstallContribNbextensionsApp] - Validating: OK
# [I 18:54:54 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.7/dist-packages/jupyter_contrib_nbextensions/nbextensions/code_prettify -> code_prettify
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/demo-jv.gif
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/README_2to3.md
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/autopep8.yaml
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/kernel_exec_on_cell.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/isort.yaml
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/autopep8.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/demo_2to3.gif
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/README.md
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/README_code_prettify.md
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/demo-py.gif
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/2to3.yaml
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/code_prettify.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/code_prettify.yaml
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/demo-R.gif
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/2to3.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/isort.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/README_isort.md
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/README_autopep8.md
# [I 18:54:54 InstallContribNbextensionsApp] - Validating: OK
# [I 18:54:54 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.7/dist-packages/jupyter_contrib_nbextensions/nbextensions/hide_input_all -> hide_input_all
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/hide_input_all/icon.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/hide_input_all/hide_input_all.yaml
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/hide_input_all/hide_input_all_hide.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/hide_input_all/main.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/hide_input_all/readme.md
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/hide_input_all/hide_input_all_show.png
# [I 18:54:54 InstallContribNbextensionsApp] - Validating: OK
# [I 18:54:54 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.7/dist-packages/jupyter_contrib_nbextensions/nbextensions/load_tex_macros -> load_tex_macros
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/load_tex_macros/icon.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/load_tex_macros/main.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/load_tex_macros/readme.md
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/load_tex_macros/load_tex_macros.yaml
# [I 18:54:54 InstallContribNbextensionsApp] - Validating: OK
# [I 18:54:54 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.7/dist-packages/jupyter_contrib_nbextensions/nbextensions/python-markdown -> python-markdown
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/python-markdown/main.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/python-markdown/untrusted.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/python-markdown/python-markdown-pre.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/python-markdown/python-markdown.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/python-markdown/python-markdown.yaml
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/python-markdown/trusted.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/python-markdown/python-markdown-post.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/python-markdown/main.css
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/python-markdown/readme.md
# [I 18:54:54 InstallContribNbextensionsApp] - Validating: OK
# [I 18:54:54 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.7/dist-packages/jupyter_contrib_nbextensions/nbextensions/autosavetime -> autosavetime
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/autosavetime/icon.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/autosavetime/main.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/autosavetime/README.md
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/autosavetime/autosavetime.yaml
# [I 18:54:54 InstallContribNbextensionsApp] - Validating: OK
# [I 18:54:54 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.7/dist-packages/jupyter_contrib_nbextensions/nbextensions/execute_time -> execute_time
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/execute_time/icon.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/execute_time/execution-timings-box.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/execute_time/ExecuteTime.yaml
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/execute_time/ExecuteTime.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/execute_time/ExecuteTime.css
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/execute_time/execution-timings-menu.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/execute_time/readme.md
# [I 18:54:54 InstallContribNbextensionsApp] - Validating: OK
# [I 18:54:54 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.7/dist-packages/jupyter_contrib_nbextensions/nbextensions/printview -> printview
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/printview/icon.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/printview/printview-button.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/printview/main.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/printview/printview.yaml
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/printview/readme.md
# [I 18:54:54 InstallContribNbextensionsApp] - Validating: OK
# [I 18:54:54 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.7/dist-packages/jupyter_contrib_nbextensions/nbextensions/varInspector -> varInspector
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/varInspector/varInspector.yaml
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/varInspector/tablesorter_LICENSE.txt
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/varInspector/icon.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/varInspector/main.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/varInspector/var_list.py
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/varInspector/README.md
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/varInspector/jquery.tablesorter.min.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/varInspector/demo.gif
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/varInspector/var_list.r
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/varInspector/main.css
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/varInspector/__pycache__/var_list.cpython-37.pyc
# [I 18:54:54 InstallContribNbextensionsApp] - Validating: OK
# [I 18:54:54 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.7/dist-packages/jupyter_contrib_nbextensions/nbextensions/code_font_size -> code_font_size
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_font_size/code_font_size.yaml
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_font_size/code_font_size.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_font_size/README.md
# [I 18:54:54 InstallContribNbextensionsApp] - Validating: OK
# [I 18:54:54 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.7/dist-packages/jupyter_contrib_nbextensions/nbextensions/execution_dependencies -> execution_dependencies
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/execution_dependencies/execution_dependencies.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/execution_dependencies/README.md
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/execution_dependencies/execution_dependencies.yml
# [I 18:54:54 InstallContribNbextensionsApp] - Validating: OK
# [I 18:54:54 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.7/dist-packages/jupyter_contrib_nbextensions/nbextensions/init_cell -> init_cell
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/init_cell/icon.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/init_cell/main.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/init_cell/README.md
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/init_cell/init_cell.yaml
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/init_cell/cell_toolbar_menu.png
# [I 18:54:54 InstallContribNbextensionsApp] - Validating: OK
# [I 18:54:54 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.7/dist-packages/jupyter_contrib_nbextensions/nbextensions/export_embedded -> export_embedded
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/export_embedded/export_embedded.yaml
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/export_embedded/icon.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/export_embedded/main.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/export_embedded/readme.md
# [I 18:54:54 InstallContribNbextensionsApp] - Validating: OK
# [I 18:54:54 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.7/dist-packages/jupyter_contrib_nbextensions/nbextensions/hide_header -> hide_header
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/hide_header/main.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/hide_header/README.md
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/hide_header/hide_header.yaml
# [I 18:54:54 InstallContribNbextensionsApp] - Validating: OK
# [I 18:54:54 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.7/dist-packages/jupyter_contrib_nbextensions/nbextensions/notify -> notify
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/notify/notification.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/notify/notify.yaml
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/notify/notify.mp3
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/notify/notify.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/notify/readme.md
# [I 18:54:54 InstallContribNbextensionsApp] - Validating: OK
# [I 18:54:54 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.7/dist-packages/jupyter_contrib_nbextensions/nbextensions/runtools -> runtools
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/runtools/runtools_lock.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/runtools/icon.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/runtools/main.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/runtools/runtools_execute.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/runtools/runtools_marker.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/runtools/demo.gif
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/runtools/gutter.css
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/runtools/runtools_nb.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/runtools/cellstate.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/runtools/annotations.odg
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/runtools/runtools_show_hide.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/runtools/main.css
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/runtools/readme.md
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/runtools/runtools.yaml
# [I 18:54:54 InstallContribNbextensionsApp] - Validating: OK
# [I 18:54:54 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.7/dist-packages/jupyter_contrib_nbextensions/nbextensions/scroll_down -> scroll_down
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/scroll_down/config.yaml
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/scroll_down/icon.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/scroll_down/main.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/scroll_down/readme.md
# [I 18:54:54 InstallContribNbextensionsApp] - Validating: OK
# [I 18:54:54 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.7/dist-packages/jupyter_contrib_nbextensions/nbextensions/splitcell -> splitcell
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/splitcell/splitcell.yaml
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/splitcell/icon.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/splitcell/splitcell.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/splitcell/readme.md
# [I 18:54:54 InstallContribNbextensionsApp] - Validating: OK
# [I 18:54:54 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.7/dist-packages/jupyter_contrib_nbextensions/nbextensions/freeze -> freeze
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/freeze/config.yaml
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/freeze/icon.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/freeze/main.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/freeze/readme.md
# [I 18:54:54 InstallContribNbextensionsApp] - Validating: OK
# [I 18:54:54 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.7/dist-packages/jupyter_contrib_nbextensions/nbextensions/keyboard_shortcut_editor -> keyboard_shortcut_editor
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/keyboard_shortcut_editor/readme_menu_item.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/keyboard_shortcut_editor/readme_dropdown.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/keyboard_shortcut_editor/readme_shortcut_editor_blank.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/keyboard_shortcut_editor/readme_undefined_key.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/keyboard_shortcut_editor/readme_comma.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/keyboard_shortcut_editor/icon.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/keyboard_shortcut_editor/readme_conflict.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/keyboard_shortcut_editor/kse_components.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/keyboard_shortcut_editor/main.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/keyboard_shortcut_editor/readme_add_new_select_action.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/keyboard_shortcut_editor/readme_shortcut_editor_success.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/keyboard_shortcut_editor/keyboard_shortcut_editor.yaml
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/keyboard_shortcut_editor/readme_add_new_link.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/keyboard_shortcut_editor/README.md
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/keyboard_shortcut_editor/quickhelp_shim.js
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/keyboard_shortcut_editor/readme_reset_disabled.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/keyboard_shortcut_editor/main.css
# [I 18:54:54 InstallContribNbextensionsApp] - Validating: OK
# [I 18:54:54 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.7/dist-packages/jupyter_contrib_nbextensions/nbextensions/gist_it -> gist_it
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/gist_it/gist_it.yaml
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/gist_it/icon.png
# [I 18:54:54 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/gist_it/main.js
# ...
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/contrib_nbextensions_help_item/main.js
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/contrib_nbextensions_help_item/README.md
# [I 18:54:55 InstallContribNbextensionsApp] - Validating: OK
# [I 18:54:55 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.7/dist-packages/jupyter_contrib_nbextensions/nbextensions/toc2 -> toc2
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/toc2/toc2.yaml
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/toc2/icon.png
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/toc2/demo_dark.png
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/toc2/main.js
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/toc2/image.png
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/toc2/demo3.gif
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/toc2/README.md
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/toc2/demo.gif
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/toc2/main.css
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/toc2/toc2.js
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/toc2/demo2.gif
# [I 18:54:55 InstallContribNbextensionsApp] - Validating: OK
# [I 18:54:55 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.7/dist-packages/jupyter_contrib_nbextensions/nbextensions/snippets_menu -> snippets_menu
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/snippets_menu/screenshot1.png
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/snippets_menu/config.yaml
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/snippets_menu/snippets_menu.css
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/snippets_menu/screenshot3.png
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/snippets_menu/examples_for_custom.js
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/snippets_menu/main.js
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/snippets_menu/thumbnail.png
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/snippets_menu/snippets_submenu_python.js
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/snippets_menu/readme.md
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/snippets_menu/snippets_submenu_markdown.js
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/snippets_menu/screenshot2.png
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/snippets_menu/snippets_submenus_python/scipy_constants.js
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/snippets_menu/snippets_submenus_python/python.js
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/snippets_menu/snippets_submenus_python/numpy_ufuncs.js
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/snippets_menu/snippets_submenus_python/numpy_polynomial.js
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/snippets_menu/snippets_submenus_python/scipy_special.js
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/snippets_menu/snippets_submenus_python/scipy.js
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/snippets_menu/snippets_submenus_python/numpy.js
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/snippets_menu/snippets_submenus_python/numba.js
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/snippets_menu/snippets_submenus_python/python_regex.js
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/snippets_menu/snippets_submenus_python/sympy_functions.js
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/snippets_menu/snippets_submenus_python/sympy.js
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/snippets_menu/snippets_submenus_python/h5py.js
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/snippets_menu/snippets_submenus_python/matplotlib.js
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/snippets_menu/snippets_submenus_python/pandas.js
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/snippets_menu/snippets_submenus_python/sympy_assumptions.js
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/snippets_menu/snippets_submenus_python/astropy.js
# [I 18:54:55 InstallContribNbextensionsApp] - Validating: OK
# [I 18:54:55 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.7/dist-packages/jupyter_contrib_nbextensions/nbextensions/hide_input -> hide_input
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/hide_input/icon.png
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/hide_input/main.js
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/hide_input/hide-input.yaml
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/hide_input/readme.md
# [I 18:54:55 InstallContribNbextensionsApp] - Validating: OK
# [I 18:54:55 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.7/dist-packages/jupyter_contrib_nbextensions/nbextensions/tree-filter -> tree-filter
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/tree-filter/tree-filter.yaml
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/tree-filter/demo.gif
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/tree-filter/readme.md
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/tree-filter/index.js
# [I 18:54:55 InstallContribNbextensionsApp] - Validating: OK
# [I 18:54:55 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.7/dist-packages/jupyter_contrib_nbextensions/nbextensions/cell_filter -> cell_filter
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/cell_filter/cell_filter.js
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/cell_filter/README.md
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/cell_filter/cell_filter.yml
# [I 18:54:55 InstallContribNbextensionsApp] - Validating: OK
# [I 18:54:55 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.7/dist-packages/jupyter_highlight_selected_word/static/highlight_selected_word -> highlight_selected_word
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/highlight_selected_word/main.js
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/highlight_selected_word/README.md
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/highlight_selected_word/configurator.yaml
# [I 18:54:55 InstallContribNbextensionsApp] - Validating: OK
# [I 18:54:55 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.7/dist-packages/latex_envs/static -> latex_envs
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/latex_envs/initNb.js
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/latex_envs/envsLatex.js
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/latex_envs/bibInNb4.js
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/latex_envs/latex_envs.js
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/latex_envs/main_toolbar.png
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/latex_envs/icon.png
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/latex_envs/latex_envs.yaml
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/latex_envs/README.md
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/latex_envs/configuration_toolbar.png
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/latex_envs/bibtex2.js
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/latex_envs/example.png
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/latex_envs/latex_envs.css
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/latex_envs/envsLatex.json
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/latex_envs/example_user_envs.json
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/latex_envs/thmsInNb4.js
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/latex_envs/doc/latex_env_doc.tex
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/latex_envs/doc/main_toolbar.png
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/latex_envs/doc/biblio_ipython.bib
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/latex_envs/doc/header.tex
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/latex_envs/doc/LaTeX_envs_menu.png
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/latex_envs/doc/IEEEtran.bst
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/latex_envs/doc/config_toolbar.png
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/latex_envs/doc/Toggles.png
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/latex_envs/doc/README.md
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/latex_envs/doc/configuration_toolbar.png
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/latex_envs/doc/example.png
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/latex_envs/doc/documentation.tex
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/latex_envs/doc/documentation.pdf
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/latex_envs/doc/latex_env_doc.html
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/latex_envs/doc/latex_env_doc.ipynb
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/latex_envs/doc/.ipynb_checkpoints/latex_env_doc-checkpoint.ipynb
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/latex_envs/doc/latex_env_doc_files/latex_env_doc_45_0.png
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/latex_envs/doc/latex_env_doc_files/latex_env_doc_50_0.png
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/latex_envs/doc/latex_env_doc_files/latex_env_doc_27_2.png
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/latex_envs/doc/latex_env_doc_files/latex_env_doc_24_2.png
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/latex_envs/doc/latex_env_doc_files/latex_env_doc_26_2.png
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/latex_envs/doc/latex_env_doc_files/latex_env_doc_41_0.png
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/latex_envs/doc/latex_env_doc_files/latex_env_doc_46_0.png
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/latex_envs/doc/latex_env_doc_files/latex_env_doc_43_0.png
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/latex_envs/doc/latex_env_doc_files/latex_env_doc_51_0.png
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/latex_envs/doc/latex_env_doc_files/latex_env_doc_44_0.png
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/latex_envs/doc/latex_env_doc_files/latex_env_doc_48_0.png
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/latex_envs/doc/latex_env_doc_files/latex_env_doc_47_0.png
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/latex_envs/doc/latex_env_doc_files/latex_env_doc_52_0.png
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/latex_envs/doc/latex_env_doc_files/latex_env_doc_42_0.png
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/latex_envs/doc/latex_env_doc_files/latex_env_doc_23_2.png
# [I 18:54:55 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/latex_envs/doc/latex_env_doc_files/latex_env_doc_49_0.png
# [I 18:54:55 InstallContribNbextensionsApp] - Validating: OK
# [I 18:54:55 InstallContribNbextensionsApp] Installing jupyter_contrib_nbextensions items to config in /root/.jupyter
# Enabling: jupyter_nbextensions_configurator
# - Writing config: /root/.jupyter
#     - Validating...
#       jupyter_nbextensions_configurator  OK
# Enabling notebook nbextension nbextensions_configurator/config_menu/main...
# Enabling tree nbextension nbextensions_configurator/tree_tab/main...
# [I 18:54:55 InstallContribNbextensionsApp] Enabling notebook extension contrib_nbextensions_help_item/main...
# [I 18:54:55 InstallContribNbextensionsApp]       - Validating: OK
# [I 18:54:55 InstallContribNbextensionsApp] - Editing config: /root/.jupyter/jupyter_nbconvert_config.json
# [I 18:54:55 InstallContribNbextensionsApp] --  Configuring nbconvert template path
# [I 18:54:55 InstallContribNbextensionsApp] --  Configuring nbconvert preprocessors
# [I 18:54:55 InstallContribNbextensionsApp] - Writing config: /root/.jupyter/jupyter_nbconvert_config.json
# [I 18:54:55 InstallContribNbextensionsApp] --  Writing updated config file /root/.jupyter/jupyter_nbconvert_config.json

# %%
#@title
# !pip install jupyter_nbextensions_configurator
# Out:
# Requirement already satisfied: jupyter_nbextensions_configurator in /usr/local/lib/python3.7/dist-packages (0.4.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from jupyter_nbextensions_configurator) (3.13)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.7/dist-packages (from jupyter_nbextensions_configurator) (4.9.1)
# Requirement already satisfied: jupyter-contrib-core>=0.3.3 in /usr/local/lib/python3.7/dist-packages (from jupyter_nbextensions_configurator) (0.3.3)
# Requirement already satisfied: traitlets in /usr/local/lib/python3.7/dist-packages (from jupyter_nbextensions_configurator) (5.1.1)
# Requirement already satisfied: notebook>=4.0 in /usr/local/lib/python3.7/dist-packages (from jupyter_nbextensions_configurator) (5.3.1)
# Requirement already satisfied: tornado in /usr/local/lib/python3.7/dist-packages (from jupyter_nbextensions_configurator) (5.1.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from jupyter-contrib-core>=0.3.3->jupyter_nbextensions_configurator) (57.4.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.0->jupyter_nbextensions_configurator) (2.11.3)
# Requirement already satisfied: jupyter-client>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.0->jupyter_nbextensions_configurator) (5.3.5)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.7/dist-packages (from notebook>=4.0->jupyter_nbextensions_configurator) (5.1.3)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.7/dist-packages (from notebook>=4.0->jupyter_nbextensions_configurator) (5.6.1)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.0->jupyter_nbextensions_configurator) (0.12.1)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from notebook>=4.0->jupyter_nbextensions_configurator) (1.8.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.7/dist-packages (from notebook>=4.0->jupyter_nbextensions_configurator) (0.2.0)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.7/dist-packages (from notebook>=4.0->jupyter_nbextensions_configurator) (4.10.1)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.7/dist-packages (from jupyter-client>=5.2.0->notebook>=4.0->jupyter_nbextensions_configurator) (22.3.0)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from jupyter-client>=5.2.0->notebook>=4.0->jupyter_nbextensions_configurator) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.1->jupyter-client>=5.2.0->notebook>=4.0->jupyter_nbextensions_configurator) (1.15.0)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.7/dist-packages (from terminado>=0.8.1->notebook>=4.0->jupyter_nbextensions_configurator) (0.7.0)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel->notebook>=4.0->jupyter_nbextensions_configurator) (5.5.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipykernel->notebook>=4.0->jupyter_nbextensions_configurator) (2.6.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipykernel->notebook>=4.0->jupyter_nbextensions_configurator) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipykernel->notebook>=4.0->jupyter_nbextensions_configurator) (0.7.5)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipykernel->notebook>=4.0->jupyter_nbextensions_configurator) (4.8.0)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipykernel->notebook>=4.0->jupyter_nbextensions_configurator) (0.8.1)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipykernel->notebook>=4.0->jupyter_nbextensions_configurator) (1.0.18)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=4.0.0->ipykernel->notebook>=4.0->jupyter_nbextensions_configurator) (0.2.5)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->notebook>=4.0->jupyter_nbextensions_configurator) (2.0.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.0->jupyter_nbextensions_configurator) (1.5.0)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.0->jupyter_nbextensions_configurator) (0.5.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.0->jupyter_nbextensions_configurator) (4.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.0->jupyter_nbextensions_configurator) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.0->jupyter_nbextensions_configurator) (0.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.0->jupyter_nbextensions_configurator) (0.8.4)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/local/lib/python3.7/dist-packages (from nbformat->notebook>=4.0->jupyter_nbextensions_configurator) (2.6.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert->notebook>=4.0->jupyter_nbextensions_configurator) (21.3)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert->notebook>=4.0->jupyter_nbextensions_configurator) (0.5.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->bleach->nbconvert->notebook>=4.0->jupyter_nbextensions_configurator) (3.0.6)

# %% [markdown]
# # DeepGBM

# %% [markdown]
# Guolin Ke, Zhenhui Xu, Jia Zhang, Jiang Bian, and Tie-yan Liu. "DeepGBM: A Deep Learning Framework Distilled  by GBDT for Online Prediction Tasks." In Proceedings of the 25th ACM SIGKDD International Conference on Knowledge Discovery & Data Mining, ACM, 2019.
#
# [Article](https://dl.acm.org/doi/10.1145/3292500.3330858)
#
# [GitHub](https://github.com/motefly/DeepGBM)

# %%
import pandas as pd
# pd.set_option('display.max_columns', 200)

# %%
import numpy as np
import category_encoders as ce
from tqdm import tqdm
import collections, os
import gc
import pdb

# %% [markdown]
# Here code for preprocessing from paper.

# %%
#@title
def unpackbits(x,num_bits):
    xshape = list(x.shape)
    x = x.reshape([-1,1])
    to_and = 2**np.arange(num_bits).reshape([1,num_bits])
    return (x & to_and).astype(bool).astype(int).reshape(xshape + [num_bits])

class NumEncoder(object):
    def __init__(self, cate_col, nume_col, threshold, thresrate, label):
        self.label_name = label
        # cate_col = list(df.select_dtypes(include=['object']))
        self.cate_col = cate_col
        # nume_col = list(set(list(df)) - set(cate_col))
        self.dtype_dict = {}
        for item in cate_col:
            self.dtype_dict[item] = 'str'
        for item in nume_col:
            self.dtype_dict[item] = 'float'
        self.nume_col = nume_col
        self.tgt_nume_col = []
        self.encoder = ce.ordinal.OrdinalEncoder(cols=cate_col)
        self.threshold = threshold
        self.thresrate = thresrate
        # for online update, to do
        self.save_cate_avgs = {}
        self.save_value_filter = {}
        self.save_num_embs = {}
        self.Max_len = {}
        self.samples = 0

    def fit_transform(self, inPath, outPath):
        print('----------------------------------------------------------------------')
        print('Fitting and Transforming %s .'%inPath)
        print('----------------------------------------------------------------------')
        df = pd.read_csv(inPath, dtype=self.dtype_dict)
        self.samples = df.shape[0]
        print('Filtering and fillna features')
        for item in tqdm(self.cate_col):
            value_counts = df[item].value_counts()
            num = value_counts.shape[0]
            self.save_value_filter[item] = list(value_counts[:int(num*self.thresrate)][value_counts>self.threshold].index)
            rm_values = set(value_counts.index)-set(self.save_value_filter[item])
            df[item] = df[item].map(lambda x: '<LESS>' if x in rm_values else x)
            df[item] = df[item].fillna('<UNK>')
            del value_counts
            gc.collect()

        for item in tqdm(self.nume_col):
            df[item] = df[item].fillna(df[item].mean())
            self.save_num_embs[item] = {'sum':df[item].sum(), 'cnt':df[item].shape[0]}

        print('Ordinal encoding cate features')
        # ordinal_encoding
        df = self.encoder.fit_transform(df)

        print('Target encoding cate features')
        # dynamic_targeting_encoding
        for item in tqdm(self.cate_col):
            feats = df[item].values
            labels = df[self.label_name].values
            feat_encoding = {'mean':[], 'count':[]}
            feat_temp_result = collections.defaultdict(lambda : [0, 0])
            self.save_cate_avgs[item] = collections.defaultdict(lambda : [0, 0])
            for idx in range(self.samples):
                cur_feat = feats[idx]
                # smoothing optional
                if cur_feat in self.save_cate_avgs[item]:
                    # feat_temp_result[cur_feat][0] = 0.9*feat_temp_result[cur_feat][0] + 0.1*self.save_cate_avgs[item][cur_feat][0]/self.save_cate_avgs[item][cur_feat][1]
                    # feat_temp_result[cur_feat][1] = 0.9*feat_temp_result[cur_feat][1] + 0.1*self.save_cate_avgs[item][cur_feat][1]/idx
                    feat_encoding['mean'].append(self.save_cate_avgs[item][cur_feat][0]/self.save_cate_avgs[item][cur_feat][1])
                    feat_encoding['count'].append(self.save_cate_avgs[item][cur_feat][1]/idx)
                else:
                    feat_encoding['mean'].append(0)
                    feat_encoding['count'].append(0)
                self.save_cate_avgs[item][cur_feat][0] += labels[idx]
                self.save_cate_avgs[item][cur_feat][1] += 1
            df[item+'_t_mean'] = feat_encoding['mean']
            df[item+'_t_count'] = feat_encoding['count']
            self.tgt_nume_col.append(item+'_t_mean')
            self.tgt_nume_col.append(item+'_t_count')
        
        print('Start manual binary encode')
        rows = None
        for item in tqdm(self.nume_col+self.tgt_nume_col):
            feats = df[item].values
            if rows is None:
                rows = feats.reshape((-1,1))
            else:
                rows = np.concatenate([rows,feats.reshape((-1,1))],axis=1)
            del feats
            gc.collect()
        for item in tqdm(self.cate_col):
            feats = df[item].values
            Max = df[item].max()
            bit_len = len(bin(Max)) - 2
            samples = self.samples
            self.Max_len[item] = bit_len
            res = unpackbits(feats, bit_len).reshape((samples,-1))
            rows = np.concatenate([rows,res],axis=1)
            del feats
            gc.collect()
        trn_y = np.array(df[self.label_name].values).reshape((-1,1))
        del df
        gc.collect()
        trn_x = np.array(rows)
        np.save(outPath+'_features.npy', trn_x)
        np.save(outPath+'_labels.npy', trn_y)

    # for test dataset
    def transform(self, inPath, outPath):
        print('----------------------------------------------------------------------')
        print('Transforming %s .'%inPath)
        print('----------------------------------------------------------------------')
        df = pd.read_csv(inPath, dtype=self.dtype_dict)
        samples = df.shape[0]
        print('Filtering and fillna features')
        for item in tqdm(self.cate_col):
            value_counts = df[item].value_counts()
            rm_values = set(value_counts.index)-set(self.save_value_filter[item])
            df[item] = df[item].map(lambda x: '<LESS>' if x in rm_values else x)
            df[item] = df[item].fillna('<UNK>')

        for item in tqdm(self.nume_col):
            mean = self.save_num_embs[item]['sum'] / self.save_num_embs[item]['cnt']
            df[item] = df[item].fillna(mean)

        print('Ordinal encoding cate features')
        # ordinal_encoding
        df = self.encoder.transform(df)

        print('Target encoding cate features')
        # dynamic_targeting_encoding
        for item in tqdm(self.cate_col):
            avgs = self.save_cate_avgs[item]
            df[item+'_t_mean'] = df[item].map(lambda x: avgs[x][0]/avgs[x][1] if x in avgs else 0)
            df[item+'_t_count'] = df[item].map(lambda x: avgs[x][1]/self.samples if x in avgs else 0)
        
        print('Start manual binary encode')
        rows = None
        for item in tqdm(self.nume_col+self.tgt_nume_col):
            feats = df[item].values
            if rows is None:
                rows = feats.reshape((-1,1))
            else:
                rows = np.concatenate([rows,feats.reshape((-1,1))],axis=1)
            del feats
            gc.collect()
        for item in tqdm(self.cate_col):
            feats = df[item].values
            bit_len = self.Max_len[item]
            res = unpackbits(feats, bit_len).reshape((samples,-1))
            rows = np.concatenate([rows,res],axis=1)
            del feats
            gc.collect()
        vld_y = np.array(df[self.label_name].values).reshape((-1,1))
        del df
        gc.collect()
        vld_x = np.array(rows)
        np.save(outPath+'_features.npy', vld_x)
        np.save(outPath+'_labels.npy', vld_y)
    
    # for update online dataset
    def refit_transform(self, inPath, outPath):
        print('----------------------------------------------------------------------')
        print('Refitting and Transforming %s .'%inPath)
        print('----------------------------------------------------------------------')
        df = pd.read_csv(inPath, dtype=self.dtype_dict)
        samples = df.shape[0]
        print('Filtering and fillna features')
        for item in tqdm(self.cate_col):
            value_counts = df[item].value_counts()
            rm_values = set(value_counts.index)-set(self.save_value_filter[item])
            df[item] = df[item].map(lambda x: '<LESS>' if x in rm_values else x)
            df[item] = df[item].fillna('<UNK>')

        for item in tqdm(self.nume_col):
            self.save_num_embs[item]['sum'] += df[item].sum()
            self.save_num_embs[item]['cnt'] += df[item].shape[0]
            mean = self.save_num_embs[item]['sum'] / self.save_num_embs[item]['cnt']
            df[item] = df[item].fillna(mean)

        print('Ordinal encoding cate features')
        # ordinal_encoding
        df = self.encoder.transform(df)

        print('Target encoding cate features')
        # dynamic_targeting_encoding
        for item in tqdm(self.cate_col):
            feats = df[item].values
            labels = df[self.label_name].values
            feat_encoding = {'mean':[], 'count':[]}
            for idx in range(samples):
                cur_feat = feats[idx]
                if self.save_cate_avgs[item][cur_feat][1] == 0:
                    pdb.set_trace()
                feat_encoding['mean'].append(self.save_cate_avgs[item][cur_feat][0]/self.save_cate_avgs[item][cur_feat][1])
                feat_encoding['count'].append(self.save_cate_avgs[item][cur_feat][1]/(self.samples+idx))
                self.save_cate_avgs[item][cur_feat][0] += labels[idx]
                self.save_cate_avgs[item][cur_feat][1] += 1
            df[item+'_t_mean'] = feat_encoding['mean']
            df[item+'_t_count'] = feat_encoding['count']

        self.samples += samples
            
        print('Start manual binary encode')
        rows = None
        for item in tqdm(self.nume_col+self.tgt_nume_col):
            feats = df[item].values
            if rows is None:
                rows = feats.reshape((-1,1))
            else:
                rows = np.concatenate([rows,feats.reshape((-1,1))],axis=1)
            del feats
            gc.collect()
        for item in tqdm(self.cate_col):
            feats = df[item].values
            bit_len = self.Max_len[item]
            res = unpackbits(feats, bit_len).reshape((samples,-1))
            rows = np.concatenate([rows,res],axis=1)
            del feats
            gc.collect()
        vld_y = np.array(df[self.label_name].values).reshape((-1,1))
        del df
        gc.collect()
        vld_x = np.array(rows)
        np.save(outPath+'_features.npy', vld_x)
        np.save(outPath+'_labels.npy', vld_y)
        # to do
        pass

# %%
#@title
class CateEncoder(object):
    def __init__(self, cate_col, nume_col, threshold, thresrate, bins, label):
        self.label_name = label
        # cate_col = list(df.select_dtypes(include=['object']))
        self.cate_col = cate_col 
        # nume_col = list(set(list(df)) - set(cate_col))
        self.dtype_dict = {}
        for item in cate_col:
            self.dtype_dict[item] = 'str'
        for item in nume_col:
            self.dtype_dict[item] = 'float'
        self.nume_col = nume_col
        self.encoder = ce.ordinal.OrdinalEncoder(cols=cate_col+nume_col)
        self.threshold = threshold
        self.thresrate = thresrate
        self.bins = bins
        # for online update, to do
        self.save_value_filter = {}
        self.save_num_bins = {}
        self.samples = 0

    def save2npy(self, df, out_dir):
        if not os.path.isdir(out_dir):
            os.mkdir(out_dir)
        result = {'label':[], 'index':[],'feature_sizes':[]}
        result['label'] = df[self.label_name].values
        result['index'] = df[self.cate_col+self.nume_col].values
        for item in self.cate_col+self.nume_col:
            result['feature_sizes'].append(df[item].max()+1)
        for item in result:
            result[item] = np.array(result[item])
            np.save(out_dir + '_' + item +'.npy', result[item])

    def fit_transform(self, inPath, outPath):
        print('----------------------------------------------------------------------')
        print('Fitting and Transforming %s .'%inPath)
        print('----------------------------------------------------------------------')
        df = pd.read_csv(inPath, dtype=self.dtype_dict)
        print('Filtering and fillna features')
        for item in tqdm(self.cate_col):
            value_counts = df[item].value_counts()
            num = value_counts.shape[0]
            self.save_value_filter[item] = list(value_counts[:int(num*self.thresrate)][value_counts>self.threshold].index)
            rm_values = set(value_counts.index)-set(self.save_value_filter[item])
            df[item] = df[item].map(lambda x: '<LESS>' if x in rm_values else x)
            df[item] = df[item].fillna('<UNK>')

        print('Fillna and Bucketize numeric features')
        for item in tqdm(self.nume_col):
            q_res = pd.qcut(df[item], self.bins, labels=False, retbins=True, duplicates='drop')
            df[item] = q_res[0].fillna(-1).astype('int')
            self.save_num_bins[item] = q_res[1]

        print('Ordinal encoding cate features')
        # ordinal_encoding
        df = self.encoder.fit_transform(df)
        self.save2npy(df, outPath)
        # df.to_csv(outPath, index=False)

    # for test dataset
    def transform(self, inPath, outPath):
        print('----------------------------------------------------------------------')
        print('Transforming %s .'%inPath)
        print('----------------------------------------------------------------------')
        df = pd.read_csv(inPath, dtype=self.dtype_dict)
        print('Filtering and fillna features')
        for item in tqdm(self.cate_col):
            value_counts = df[item].value_counts()
            rm_values = set(value_counts.index)-set(self.save_value_filter[item])
            df[item] = df[item].map(lambda x: '<LESS>' if x in rm_values else x)
            df[item] = df[item].fillna('<UNK>')

        for item in tqdm(self.nume_col):
            df[item] = pd.cut(df[item], self.save_num_bins[item], labels=False, include_lowest=True).fillna(-1).astype('int')

        print('Ordinal encoding cate features')
        # ordinal_encoding
        df = self.encoder.transform(df)
        self.save2npy(df, outPath)
        # df.to_csv(outPath, index=False)

# %% [markdown]
# ## Data loading

# %%
# file_url = "http://storage.googleapis.com/download.tensorflow.org/data/heart.csv"
file_url = "https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv"
# file_url = "https://storage.yandexcloud.net/datasouls-ods/materials/3b9757b5/train_data.csv"
# file_url = "https://download.mlcc.google.com/mledu-datasets/california_housing_train.csv"
df = pd.read_csv(file_url, sep=';')
df.head(2)
# Out:
#    fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0            7.0              0.27         0.36  ...       0.45      8.8        6
# 1            6.3              0.30         0.34  ...       0.49      9.5        6
#
# [2 rows x 12 columns]

# %%
nume_col = df.select_dtypes('number').columns.tolist()
cate_col = df.select_dtypes('object').columns.tolist()
label_col = 'quality'

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test = train_test_split(
    df, test_size=0.2, random_state=42)

# %%
out_dir = '/content/drive/MyDrive/DeepGBM/experiments/data/data_offline'
threshold = 10
thresrate = 0.99
num_bins = 32
test_csv_path = os.path.join(out_dir, 'test.csv')
train_csv_path = os.path.join(out_dir, 'train.csv')

# %%
X_train.to_csv(train_csv_path)
X_test.to_csv(test_csv_path)

# %% [markdown]
# ## Numeric feature preprocessing

# %%
out_dir_num = '/content/drive/MyDrive/DeepGBM/experiments/data/data_offline_num'
if not os.path.isdir(out_dir_num):
        os.mkdir(out_dir_num)
ec = NumEncoder(cate_col, nume_col, threshold, thresrate, label_col)
ec.fit_transform(train_csv_path, out_dir_num + '/train')
ec.transform(test_csv_path, out_dir_num + '/test')
# Out:
# ----------------------------------------------------------------------
# Fitting and Transforming /content/drive/MyDrive/DeepGBM/experiments/data/data_offline/train.csv .
# ----------------------------------------------------------------------
# Filtering and fillna features
# 0it [00:00, ?it/s]
# 100%|██████████| 12/12 [00:00<00:00, 613.90it/s]
# Ordinal encoding cate features
# Target encoding cate features
# 0it [00:00, ?it/s]
# Start manual binary encode
# 100%|██████████| 12/12 [00:01<00:00, 10.41it/s]
# 0it [00:00, ?it/s]
# ----------------------------------------------------------------------
# Transforming /content/drive/MyDrive/DeepGBM/experiments/data/data_offline/test.csv .
# ----------------------------------------------------------------------
# Filtering and fillna features
# 0it [00:00, ?it/s]
# 100%|██████████| 12/12 [00:00<00:00, 1559.46it/s]
# Ordinal encoding cate features
# Target encoding cate features
# 0it [00:00, ?it/s]
# Start manual binary encode
# 100%|██████████| 12/12 [00:00<00:00, 13.16it/s]
# 0it [00:00, ?it/s]

# %% [markdown]
# ## Categorical features preprocessing

# %%
out_dir_cate = '/content/drive/MyDrive/DeepGBM/experiments/data/data_offline_cate'
if not os.path.isdir(out_dir_cate):
        os.mkdir(out_dir_cate)
ec = CateEncoder(cate_col, nume_col, threshold, thresrate, num_bins, label_col)
ec.fit_transform(train_csv_path, out_dir_cate + '/train/')
ec.transform(test_csv_path, out_dir_cate + '/test/')
# Out:
# ----------------------------------------------------------------------
# Fitting and Transforming /content/drive/MyDrive/DeepGBM/experiments/data/data_offline/train.csv .
# ----------------------------------------------------------------------
# Filtering and fillna features
# 0it [00:00, ?it/s]
# Fillna and Bucketize numeric features
# 100%|██████████| 12/12 [00:00<00:00, 293.22it/s]
# Ordinal encoding cate features
# ----------------------------------------------------------------------
# Transforming /content/drive/MyDrive/DeepGBM/experiments/data/data_offline/test.csv .
# ----------------------------------------------------------------------
# Filtering and fillna features
# 0it [00:00, ?it/s]
# 100%|██████████| 12/12 [00:00<00:00, 501.93it/s]
# Ordinal encoding cate features

# %%
import sys
sys.path.insert(0, '/content/drive/MyDrive/DeepGBM/experiments/data/models')

# %%
# !python /content/drive/MyDrive/DeepGBM/experiments/data/main.py -data data_offline -batch_size 512 -plot_title 'paper_0201' \
-max_epoch 20 -lr 1e-3 -opt Adam -test_batch_size 100 -model deepgbm \
-task regression -l2_reg 1e-6 -test_freq 300 -seed 1,2,3,4,5 -group_method Random \
-emb_epoch 2 -loss_de 2 -loss_dr 0.7 -tree_lr 0.1 -cate_layers 16,16 -nslices 5 \
 -tree_layers 100,100,100,50 -embsize 20 -maxleaf 64 -log_freq 500
# Out:
# 2021-12-26 19:02:06,100 [INFO] data loaded.
#  train_x shape: (3918, 12). train_y shape: (3918, 1).
#  test_x shape: (980, 12). test_y shape: (980, 1).
# loaded from /content/drive/MyDrive/DeepGBM/experiments/data/data_offline_cate/train/.
# loaded from /content/drive/MyDrive/DeepGBM/experiments/data/data_offline_cate/test/.
# 2021-12-26 19:02:06,113 [INFO] Categorical data loaded.
#  train_x shape: (3918, 12). train_y shape: (3918, 1).
#  test_x shape: (980, 12). test_y shape: (980, 1).
# [LightGBM] [Info] Total Bins 1349
# [LightGBM] [Info] Number of data: 3918, number of used features: 12
# [LightGBM] [Info] Start training from score 5.871363
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	valid_0's l2: 0.629356
# Training until validation scores don't improve for 20 rounds.
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	valid_0's l2: 0.510817
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	valid_0's l2: 0.414886
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	valid_0's l2: 0.337218
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	valid_0's l2: 0.273997
# [6]	valid_0's l2: 0.256411
# [7]	valid_0's l2: 0.208742
# [8]	valid_0's l2: 0.170341
# [9]	valid_0's l2: 0.139027
# [10]	valid_0's l2: 0.113654
# [11]	valid_0's l2: 0.0930975
# [12]	valid_0's l2: 0.0765135
# [13]	valid_0's l2: 0.0724661
# [14]	valid_0's l2: 0.0689942
# [15]	valid_0's l2: 0.0571532
# [16]	valid_0's l2: 0.0475474
# [17]	valid_0's l2: 0.0397408
# [18]	valid_0's l2: 0.0335058
# [19]	valid_0's l2: 0.0283291
# [20]	valid_0's l2: 0.0241274
# [21]	valid_0's l2: 0.0207642
# [22]	valid_0's l2: 0.0202563
# [23]	valid_0's l2: 0.0177304
# [24]	valid_0's l2: 0.0155694
# [25]	valid_0's l2: 0.015261
# [26]	valid_0's l2: 0.0135065
# [27]	valid_0's l2: 0.0121069
# [28]	valid_0's l2: 0.0109829
# [29]	valid_0's l2: 0.0100783
# [30]	valid_0's l2: 0.00932073
# [31]	valid_0's l2: 0.00870742
# [32]	valid_0's l2: 0.00822125
# [33]	valid_0's l2: 0.00781547
# [34]	valid_0's l2: 0.00744067
# [35]	valid_0's l2: 0.00713549
# [36]	valid_0's l2: 0.00688029
# [37]	valid_0's l2: 0.00670534
# [38]	valid_0's l2: 0.00652697
# [39]	valid_0's l2: 0.00638391
# [40]	valid_0's l2: 0.00630702
# [41]	valid_0's l2: 0.00621517
# [42]	valid_0's l2: 0.00613314
# [43]	valid_0's l2: 0.00611324
# [44]	valid_0's l2: 0.00601507
# [45]	valid_0's l2: 0.00595458
# [46]	valid_0's l2: 0.00590605
# [47]	valid_0's l2: 0.00588299
# [48]	valid_0's l2: 0.0058669
# [49]	valid_0's l2: 0.00589095
# [50]	valid_0's l2: 0.00586091
# [51]	valid_0's l2: 0.00584415
# [52]	valid_0's l2: 0.00584738
# [53]	valid_0's l2: 0.00585094
# [54]	valid_0's l2: 0.00584494
# [55]	valid_0's l2: 0.00580542
# [56]	valid_0's l2: 0.00580564
# [57]	valid_0's l2: 0.00576667
# [58]	valid_0's l2: 0.00576673
# [59]	valid_0's l2: 0.00570703
# [60]	valid_0's l2: 0.00570289
# [61]	valid_0's l2: 0.00568108
# [62]	valid_0's l2: 0.00566949
# [63]	valid_0's l2: 0.00564451
# [64]	valid_0's l2: 0.00563686
# [65]	valid_0's l2: 0.00559653
# [66]	valid_0's l2: 0.00558021
# [67]	valid_0's l2: 0.00559034
# [68]	valid_0's l2: 0.00558846
# [69]	valid_0's l2: 0.0055862
# [70]	valid_0's l2: 0.00554011
# [71]	valid_0's l2: 0.00557232
# [72]	valid_0's l2: 0.00554418
# [73]	valid_0's l2: 0.00553195
# [74]	valid_0's l2: 0.00552077
# [75]	valid_0's l2: 0.00550946
# [76]	valid_0's l2: 0.00551035
# [77]	valid_0's l2: 0.00551961
# [78]	valid_0's l2: 0.00553589
# [79]	valid_0's l2: 0.00548306
# [80]	valid_0's l2: 0.00544238
# [81]	valid_0's l2: 0.00540725
# [82]	valid_0's l2: 0.0054181
# [83]	valid_0's l2: 0.00540774
# [84]	valid_0's l2: 0.00541232
# [85]	valid_0's l2: 0.00540801
# [86]	valid_0's l2: 0.00544474
# [87]	valid_0's l2: 0.00548012
# [88]	valid_0's l2: 0.00549482
# [89]	valid_0's l2: 0.00549382
# [90]	valid_0's l2: 0.00549879
# [91]	valid_0's l2: 0.00547615
# [92]	valid_0's l2: 0.00548129
# [93]	valid_0's l2: 0.00550444
# [94]	valid_0's l2: 0.00550906
# [95]	valid_0's l2: 0.00552306
# [96]	valid_0's l2: 0.00551861
# [97]	valid_0's l2: 0.00547211
# [98]	valid_0's l2: 0.00543052
# [99]	valid_0's l2: 0.00542829
# [100]	valid_0's l2: 0.00542572
# Did not meet early stopping. Best iteration is:
# [81]	valid_0's l2: 0.00540725
# Model Interpreting...
# [(17,), (16,), (16,), (16,), (16,)]
# emb-Evaluate Result:
# Epoch-000     8 Batches, Step      8, Testing Loss: 37.613513, Used Time:   0.0m, Remaining Time:   0.0m
# -------------------------------------------------------------------------------
# Best Metric: 37.61351340157645
# ####################################################################################
# emb-Evaluate Result:
# Epoch-001     8 Batches, Step     16, Testing Loss: 37.211159, Used Time:   0.0m, Remaining Time:   0.0m
# -------------------------------------------------------------------------------
# Best Metric: 37.21115851888851
# ####################################################################################
# Final Best Metric: 37.21115851888851
# Init GBDT2NN
# Init GBDT2NN succeed!
# Cuda is not available, automatically changed into cpu model
# The model is deepfm(fm+deep layers)
# Init fm part
# Init fm part succeed
# Init deep part
# Init deep part succeed
# Init succeed
# Init DeepGBM succeed!
# Alpha: Parameter containing:
# tensor(0., requires_grad=True)
# Beta: Parameter containing:
# tensor(0., requires_grad=True)
# Evaluate Result:
# Epoch-000     8 Batches, Step      8, Testing Loss: 39.635373, Used Time:   0.0m, Remaining Time:   0.2m
# -------------------------------------------------------------------------------
# Best Metric: 39.635372862523916
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0., requires_grad=True)
# Beta: Parameter containing:
# tensor(0., requires_grad=True)
# Evaluate Result:
# Epoch-001     8 Batches, Step     16, Testing Loss: 38.043109, Used Time:   0.0m, Remaining Time:   0.2m
# -------------------------------------------------------------------------------
# Best Metric: 38.04310888173629
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0051, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0067, requires_grad=True)
# Evaluate Result:
# Epoch-002     8 Batches, Step     24, Testing Loss: 11.937356, Used Time:   0.0m, Remaining Time:   0.2m
# -------------------------------------------------------------------------------
# Best Metric: 11.937356364970304
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0131, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0137, requires_grad=True)
# Evaluate Result:
# Epoch-003     8 Batches, Step     32, Testing Loss:  1.841201, Used Time:   0.0m, Remaining Time:   0.2m
# -------------------------------------------------------------------------------
# Best Metric: 1.8412007725968653
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0099, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0140, requires_grad=True)
# Evaluate Result:
# Epoch-004     8 Batches, Step     40, Testing Loss:  0.892849, Used Time:   0.1m, Remaining Time:   0.2m
# -------------------------------------------------------------------------------
# Best Metric: 0.8928486254750466
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0058, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0128, requires_grad=True)
# Evaluate Result:
# Epoch-005     8 Batches, Step     48, Testing Loss:  1.350435, Used Time:   0.1m, Remaining Time:   0.2m
# -------------------------------------------------------------------------------
# Best Metric: 0.8928486254750466
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0092, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0151, requires_grad=True)
# Evaluate Result:
# Epoch-006     8 Batches, Step     56, Testing Loss:  0.418851, Used Time:   0.1m, Remaining Time:   0.2m
# -------------------------------------------------------------------------------
# Best Metric: 0.4188506925592617
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0115, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0165, requires_grad=True)
# Evaluate Result:
# Epoch-007     8 Batches, Step     64, Testing Loss:  0.338010, Used Time:   0.1m, Remaining Time:   0.1m
# -------------------------------------------------------------------------------
# Best Metric: 0.33800974123331967
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0118, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0166, requires_grad=True)
# Evaluate Result:
# Epoch-008     8 Batches, Step     72, Testing Loss:  0.349655, Used Time:   0.1m, Remaining Time:   0.1m
# -------------------------------------------------------------------------------
# Best Metric: 0.33800974123331967
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0144, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0182, requires_grad=True)
# Evaluate Result:
# Epoch-009     8 Batches, Step     80, Testing Loss:  0.241514, Used Time:   0.1m, Remaining Time:   0.1m
# -------------------------------------------------------------------------------
# Best Metric: 0.24151388601380952
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0162, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0191, requires_grad=True)
# Evaluate Result:
# Epoch-010     8 Batches, Step     88, Testing Loss:  0.238270, Used Time:   0.1m, Remaining Time:   0.1m
# -------------------------------------------------------------------------------
# Best Metric: 0.23827043145286794
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0180, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0201, requires_grad=True)
# Evaluate Result:
# Epoch-011     8 Batches, Step     96, Testing Loss:  0.227301, Used Time:   0.1m, Remaining Time:   0.1m
# -------------------------------------------------------------------------------
# Best Metric: 0.2273010784874157
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0202, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0217, requires_grad=True)
# Evaluate Result:
# Epoch-012     8 Batches, Step    104, Testing Loss:  0.213766, Used Time:   0.1m, Remaining Time:   0.1m
# -------------------------------------------------------------------------------
# Best Metric: 0.21376633948209334
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0222, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0233, requires_grad=True)
# Evaluate Result:
# Epoch-013     8 Batches, Step    112, Testing Loss:  0.190613, Used Time:   0.2m, Remaining Time:   0.1m
# -------------------------------------------------------------------------------
# Best Metric: 0.190613397530147
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0241, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0250, requires_grad=True)
# Evaluate Result:
# Epoch-014     8 Batches, Step    120, Testing Loss:  0.204321, Used Time:   0.2m, Remaining Time:   0.1m
# -------------------------------------------------------------------------------
# Best Metric: 0.190613397530147
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0256, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0269, requires_grad=True)
# Evaluate Result:
# Epoch-015     8 Batches, Step    128, Testing Loss:  0.198980, Used Time:   0.2m, Remaining Time:   0.0m
# -------------------------------------------------------------------------------
# Best Metric: 0.190613397530147
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0270, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0287, requires_grad=True)
# Evaluate Result:
# Epoch-016     8 Batches, Step    136, Testing Loss:  0.173852, Used Time:   0.2m, Remaining Time:   0.0m
# -------------------------------------------------------------------------------
# Best Metric: 0.17385232129267283
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0283, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0311, requires_grad=True)
# Evaluate Result:
# Epoch-017     8 Batches, Step    144, Testing Loss:  0.197713, Used Time:   0.2m, Remaining Time:   0.0m
# -------------------------------------------------------------------------------
# Best Metric: 0.17385232129267283
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0291, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0328, requires_grad=True)
# Evaluate Result:
# Epoch-018     8 Batches, Step    152, Testing Loss:  0.172001, Used Time:   0.2m, Remaining Time:   0.0m
# -------------------------------------------------------------------------------
# Best Metric: 0.1720010277872183
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0298, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0341, requires_grad=True)
# Evaluate Result:
# Epoch-019     8 Batches, Step    160, Testing Loss:  0.165713, Used Time:   0.2m, Remaining Time:   0.0m
# -------------------------------------------------------------------------------
# Best Metric: 0.16571312595386894
# ####################################################################################
# Final Best Metric: 0.16571312595386894
# Final metrics: 0.16571313
# Init GBDT2NN
# Init GBDT2NN succeed!
# Cuda is not available, automatically changed into cpu model
# The model is deepfm(fm+deep layers)
# Init fm part
# Init fm part succeed
# Init deep part
# Init deep part succeed
# Init succeed
# Init DeepGBM succeed!
# Alpha: Parameter containing:
# tensor(0., requires_grad=True)
# Beta: Parameter containing:
# tensor(0., requires_grad=True)
# Evaluate Result:
# Epoch-000     8 Batches, Step      8, Testing Loss: 30.874486, Used Time:   0.0m, Remaining Time:   0.2m
# -------------------------------------------------------------------------------
# Best Metric: 30.87448567760234
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0., requires_grad=True)
# Beta: Parameter containing:
# tensor(0., requires_grad=True)
# Evaluate Result:
# Epoch-001     8 Batches, Step     16, Testing Loss: 30.144715, Used Time:   0.0m, Remaining Time:   0.2m
# -------------------------------------------------------------------------------
# Best Metric: 30.144714627947128
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0069, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0067, requires_grad=True)
# Evaluate Result:
# Epoch-002     8 Batches, Step     24, Testing Loss:  6.511526, Used Time:   0.0m, Remaining Time:   0.2m
# -------------------------------------------------------------------------------
# Best Metric: 6.511525854772451
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0142, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0134, requires_grad=True)
# Evaluate Result:
# Epoch-003     8 Batches, Step     32, Testing Loss:  0.690983, Used Time:   0.0m, Remaining Time:   0.2m
# -------------------------------------------------------------------------------
# Best Metric: 0.6909833933625903
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0106, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0114, requires_grad=True)
# Evaluate Result:
# Epoch-004     8 Batches, Step     40, Testing Loss:  0.812384, Used Time:   0.1m, Remaining Time:   0.2m
# -------------------------------------------------------------------------------
# Best Metric: 0.6909833933625903
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0088, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0100, requires_grad=True)
# Evaluate Result:
# Epoch-005     8 Batches, Step     48, Testing Loss:  1.048253, Used Time:   0.1m, Remaining Time:   0.1m
# -------------------------------------------------------------------------------
# Best Metric: 0.6909833933625903
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0130, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0123, requires_grad=True)
# Evaluate Result:
# Epoch-006     8 Batches, Step     56, Testing Loss:  0.381939, Used Time:   0.1m, Remaining Time:   0.1m
# -------------------------------------------------------------------------------
# Best Metric: 0.38193936281058255
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0141, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0123, requires_grad=True)
# Evaluate Result:
# Epoch-007     8 Batches, Step     64, Testing Loss:  0.321023, Used Time:   0.1m, Remaining Time:   0.1m
# -------------------------------------------------------------------------------
# Best Metric: 0.32102252025993505
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0152, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0127, requires_grad=True)
# Evaluate Result:
# Epoch-008     8 Batches, Step     72, Testing Loss:  0.297115, Used Time:   0.1m, Remaining Time:   0.1m
# -------------------------------------------------------------------------------
# Best Metric: 0.29711525963277235
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0179, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0144, requires_grad=True)
# Evaluate Result:
# Epoch-009     8 Batches, Step     80, Testing Loss:  0.213792, Used Time:   0.1m, Remaining Time:   0.1m
# -------------------------------------------------------------------------------
# Best Metric: 0.2137919491042896
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0194, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0149, requires_grad=True)
# Evaluate Result:
# Epoch-010     8 Batches, Step     88, Testing Loss:  0.239401, Used Time:   0.1m, Remaining Time:   0.1m
# -------------------------------------------------------------------------------
# Best Metric: 0.2137919491042896
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0218, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0169, requires_grad=True)
# Evaluate Result:
# Epoch-011     8 Batches, Step     96, Testing Loss:  0.205530, Used Time:   0.1m, Remaining Time:   0.1m
# -------------------------------------------------------------------------------
# Best Metric: 0.20553038679823585
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0239, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0188, requires_grad=True)
# Evaluate Result:
# Epoch-012     8 Batches, Step    104, Testing Loss:  0.209384, Used Time:   0.1m, Remaining Time:   0.1m
# -------------------------------------------------------------------------------
# Best Metric: 0.20553038679823585
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0260, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0218, requires_grad=True)
# Evaluate Result:
# Epoch-013     8 Batches, Step    112, Testing Loss:  0.183957, Used Time:   0.1m, Remaining Time:   0.1m
# -------------------------------------------------------------------------------
# Best Metric: 0.18395686514523565
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0280, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0252, requires_grad=True)
# Evaluate Result:
# Epoch-014     8 Batches, Step    120, Testing Loss:  0.184164, Used Time:   0.2m, Remaining Time:   0.1m
# -------------------------------------------------------------------------------
# Best Metric: 0.18395686514523565
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0297, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0288, requires_grad=True)
# Evaluate Result:
# Epoch-015     8 Batches, Step    128, Testing Loss:  0.181577, Used Time:   0.2m, Remaining Time:   0.0m
# -------------------------------------------------------------------------------
# Best Metric: 0.18157742765485024
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0311, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0325, requires_grad=True)
# Evaluate Result:
# Epoch-016     8 Batches, Step    136, Testing Loss:  0.192191, Used Time:   0.2m, Remaining Time:   0.0m
# -------------------------------------------------------------------------------
# Best Metric: 0.18157742765485024
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0323, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0346, requires_grad=True)
# Evaluate Result:
# Epoch-017     8 Batches, Step    144, Testing Loss:  0.183149, Used Time:   0.2m, Remaining Time:   0.0m
# -------------------------------------------------------------------------------
# Best Metric: 0.18157742765485024
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0333, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0367, requires_grad=True)
# Evaluate Result:
# Epoch-018     8 Batches, Step    152, Testing Loss:  0.183914, Used Time:   0.2m, Remaining Time:   0.0m
# -------------------------------------------------------------------------------
# Best Metric: 0.18157742765485024
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0342, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0393, requires_grad=True)
# Evaluate Result:
# Epoch-019     8 Batches, Step    160, Testing Loss:  0.190461, Used Time:   0.2m, Remaining Time:   0.0m
# -------------------------------------------------------------------------------
# Best Metric: 0.18157742765485024
# ####################################################################################
# Final Best Metric: 0.18157742765485024
# Final metrics: 0.19046094
# Init GBDT2NN
# Init GBDT2NN succeed!
# Cuda is not available, automatically changed into cpu model
# The model is deepfm(fm+deep layers)
# Init fm part
# Init fm part succeed
# Init deep part
# Init deep part succeed
# Init succeed
# Init DeepGBM succeed!
# Alpha: Parameter containing:
# tensor(0., requires_grad=True)
# Beta: Parameter containing:
# tensor(0., requires_grad=True)
# Evaluate Result:
# Epoch-000     8 Batches, Step      8, Testing Loss: 35.054899, Used Time:   0.0m, Remaining Time:   0.2m
# -------------------------------------------------------------------------------
# Best Metric: 35.05489933247469
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0., requires_grad=True)
# Beta: Parameter containing:
# tensor(0., requires_grad=True)
# Evaluate Result:
# Epoch-001     8 Batches, Step     16, Testing Loss: 35.368646, Used Time:   0.0m, Remaining Time:   0.2m
# -------------------------------------------------------------------------------
# Best Metric: 35.05489933247469
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0017, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0068, requires_grad=True)
# Evaluate Result:
# Epoch-002     8 Batches, Step     24, Testing Loss: 10.471346, Used Time:   0.0m, Remaining Time:   0.2m
# -------------------------------------------------------------------------------
# Best Metric: 10.471346173967634
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0091, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0138, requires_grad=True)
# Evaluate Result:
# Epoch-003     8 Batches, Step     32, Testing Loss:  1.135509, Used Time:   0.0m, Remaining Time:   0.2m
# -------------------------------------------------------------------------------
# Best Metric: 1.1355094970489035
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0054, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0134, requires_grad=True)
# Evaluate Result:
# Epoch-004     8 Batches, Step     40, Testing Loss:  0.610749, Used Time:   0.1m, Remaining Time:   0.2m
# -------------------------------------------------------------------------------
# Best Metric: 0.6107492227943576
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0014, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0116, requires_grad=True)
# Evaluate Result:
# Epoch-005     8 Batches, Step     48, Testing Loss:  0.923413, Used Time:   0.1m, Remaining Time:   0.1m
# -------------------------------------------------------------------------------
# Best Metric: 0.6107492227943576
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0045, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0135, requires_grad=True)
# Evaluate Result:
# Epoch-006     8 Batches, Step     56, Testing Loss:  0.362626, Used Time:   0.1m, Remaining Time:   0.1m
# -------------------------------------------------------------------------------
# Best Metric: 0.36262616515159607
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0069, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0148, requires_grad=True)
# Evaluate Result:
# Epoch-007     8 Batches, Step     64, Testing Loss:  0.301440, Used Time:   0.1m, Remaining Time:   0.1m
# -------------------------------------------------------------------------------
# Best Metric: 0.30144008963691943
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0075, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0149, requires_grad=True)
# Evaluate Result:
# Epoch-008     8 Batches, Step     72, Testing Loss:  0.295052, Used Time:   0.1m, Remaining Time:   0.1m
# -------------------------------------------------------------------------------
# Best Metric: 0.29505210628314893
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0102, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0164, requires_grad=True)
# Evaluate Result:
# Epoch-009     8 Batches, Step     80, Testing Loss:  0.273116, Used Time:   0.1m, Remaining Time:   0.1m
# -------------------------------------------------------------------------------
# Best Metric: 0.27311648215566364
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0120, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0173, requires_grad=True)
# Evaluate Result:
# Epoch-010     8 Batches, Step     88, Testing Loss:  0.226700, Used Time:   0.1m, Remaining Time:   0.1m
# -------------------------------------------------------------------------------
# Best Metric: 0.22669966397236804
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0140, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0184, requires_grad=True)
# Evaluate Result:
# Epoch-011     8 Batches, Step     96, Testing Loss:  0.193431, Used Time:   0.1m, Remaining Time:   0.1m
# -------------------------------------------------------------------------------
# Best Metric: 0.19343122748696073
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0164, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0200, requires_grad=True)
# Evaluate Result:
# Epoch-012     8 Batches, Step    104, Testing Loss:  0.170474, Used Time:   0.1m, Remaining Time:   0.1m
# -------------------------------------------------------------------------------
# Best Metric: 0.1704739575483361
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0185, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0215, requires_grad=True)
# Evaluate Result:
# Epoch-013     8 Batches, Step    112, Testing Loss:  0.156174, Used Time:   0.1m, Remaining Time:   0.1m
# -------------------------------------------------------------------------------
# Best Metric: 0.15617411005861906
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0207, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0235, requires_grad=True)
# Evaluate Result:
# Epoch-014     8 Batches, Step    120, Testing Loss:  0.156138, Used Time:   0.2m, Remaining Time:   0.1m
# -------------------------------------------------------------------------------
# Best Metric: 0.15613793992266364
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0227, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0258, requires_grad=True)
# Evaluate Result:
# Epoch-015     8 Batches, Step    128, Testing Loss:  0.150015, Used Time:   0.2m, Remaining Time:   0.0m
# -------------------------------------------------------------------------------
# Best Metric: 0.15001530124216664
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0243, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0282, requires_grad=True)
# Evaluate Result:
# Epoch-016     8 Batches, Step    136, Testing Loss:  0.152305, Used Time:   0.2m, Remaining Time:   0.0m
# -------------------------------------------------------------------------------
# Best Metric: 0.15001530124216664
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0257, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0311, requires_grad=True)
# Evaluate Result:
# Epoch-017     8 Batches, Step    144, Testing Loss:  0.156662, Used Time:   0.2m, Remaining Time:   0.0m
# -------------------------------------------------------------------------------
# Best Metric: 0.15001530124216664
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0266, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0323, requires_grad=True)
# Evaluate Result:
# Epoch-018     8 Batches, Step    152, Testing Loss:  0.139107, Used Time:   0.2m, Remaining Time:   0.0m
# -------------------------------------------------------------------------------
# Best Metric: 0.13910708941367209
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0276, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0349, requires_grad=True)
# Evaluate Result:
# Epoch-019     8 Batches, Step    160, Testing Loss:  0.159705, Used Time:   0.2m, Remaining Time:   0.0m
# -------------------------------------------------------------------------------
# Best Metric: 0.13910708941367209
# ####################################################################################
# Final Best Metric: 0.13910708941367209
# Final metrics: 0.15970464
# Init GBDT2NN
# Init GBDT2NN succeed!
# Cuda is not available, automatically changed into cpu model
# The model is deepfm(fm+deep layers)
# Init fm part
# Init fm part succeed
# Init deep part
# Init deep part succeed
# Init succeed
# Init DeepGBM succeed!
# Alpha: Parameter containing:
# tensor(0., requires_grad=True)
# Beta: Parameter containing:
# tensor(0., requires_grad=True)
# Evaluate Result:
# Epoch-000     8 Batches, Step      8, Testing Loss: 38.451607, Used Time:   0.0m, Remaining Time:   0.2m
# -------------------------------------------------------------------------------
# Best Metric: 38.451606828339244
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0., requires_grad=True)
# Beta: Parameter containing:
# tensor(0., requires_grad=True)
# Evaluate Result:
# Epoch-001     8 Batches, Step     16, Testing Loss: 37.617152, Used Time:   0.0m, Remaining Time:   0.2m
# -------------------------------------------------------------------------------
# Best Metric: 37.61715192210917
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0018, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0067, requires_grad=True)
# Evaluate Result:
# Epoch-002     8 Batches, Step     24, Testing Loss: 11.674642, Used Time:   0.0m, Remaining Time:   0.2m
# -------------------------------------------------------------------------------
# Best Metric: 11.674642485015246
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0094, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0143, requires_grad=True)
# Evaluate Result:
# Epoch-003     8 Batches, Step     32, Testing Loss:  1.736496, Used Time:   0.0m, Remaining Time:   0.2m
# -------------------------------------------------------------------------------
# Best Metric: 1.7364956554101438
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0060, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0121, requires_grad=True)
# Evaluate Result:
# Epoch-004     8 Batches, Step     40, Testing Loss:  0.938654, Used Time:   0.1m, Remaining Time:   0.2m
# -------------------------------------------------------------------------------
# Best Metric: 0.9386540395872933
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0014, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0083, requires_grad=True)
# Evaluate Result:
# Epoch-005     8 Batches, Step     48, Testing Loss:  1.220288, Used Time:   0.1m, Remaining Time:   0.1m
# -------------------------------------------------------------------------------
# Best Metric: 0.9386540395872933
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0043, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0090, requires_grad=True)
# Evaluate Result:
# Epoch-006     8 Batches, Step     56, Testing Loss:  0.394640, Used Time:   0.1m, Remaining Time:   0.1m
# -------------------------------------------------------------------------------
# Best Metric: 0.3946400552379842
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0069, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0097, requires_grad=True)
# Evaluate Result:
# Epoch-007     8 Batches, Step     64, Testing Loss:  0.307514, Used Time:   0.1m, Remaining Time:   0.1m
# -------------------------------------------------------------------------------
# Best Metric: 0.30751413289381535
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0074, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0093, requires_grad=True)
# Evaluate Result:
# Epoch-008     8 Batches, Step     72, Testing Loss:  0.285669, Used Time:   0.1m, Remaining Time:   0.1m
# -------------------------------------------------------------------------------
# Best Metric: 0.28566933256022786
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0097, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0104, requires_grad=True)
# Evaluate Result:
# Epoch-009     8 Batches, Step     80, Testing Loss:  0.238472, Used Time:   0.1m, Remaining Time:   0.1m
# -------------------------------------------------------------------------------
# Best Metric: 0.23847185713904245
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0119, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0112, requires_grad=True)
# Evaluate Result:
# Epoch-010     8 Batches, Step     88, Testing Loss:  0.227017, Used Time:   0.1m, Remaining Time:   0.1m
# -------------------------------------------------------------------------------
# Best Metric: 0.22701653503641792
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0136, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0117, requires_grad=True)
# Evaluate Result:
# Epoch-011     8 Batches, Step     96, Testing Loss:  0.233754, Used Time:   0.1m, Remaining Time:   0.1m
# -------------------------------------------------------------------------------
# Best Metric: 0.22701653503641792
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0160, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0129, requires_grad=True)
# Evaluate Result:
# Epoch-012     8 Batches, Step    104, Testing Loss:  0.201893, Used Time:   0.1m, Remaining Time:   0.1m
# -------------------------------------------------------------------------------
# Best Metric: 0.20189322318349565
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0183, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0142, requires_grad=True)
# Evaluate Result:
# Epoch-013     8 Batches, Step    112, Testing Loss:  0.172875, Used Time:   0.1m, Remaining Time:   0.1m
# -------------------------------------------------------------------------------
# Best Metric: 0.17287497252834086
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0204, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0156, requires_grad=True)
# Evaluate Result:
# Epoch-014     8 Batches, Step    120, Testing Loss:  0.215946, Used Time:   0.2m, Remaining Time:   0.1m
# -------------------------------------------------------------------------------
# Best Metric: 0.17287497252834086
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0228, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0181, requires_grad=True)
# Evaluate Result:
# Epoch-015     8 Batches, Step    128, Testing Loss:  0.166641, Used Time:   0.2m, Remaining Time:   0.0m
# -------------------------------------------------------------------------------
# Best Metric: 0.16664100803282797
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0249, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0204, requires_grad=True)
# Evaluate Result:
# Epoch-016     8 Batches, Step    136, Testing Loss:  0.181316, Used Time:   0.2m, Remaining Time:   0.0m
# -------------------------------------------------------------------------------
# Best Metric: 0.16664100803282797
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0270, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0241, requires_grad=True)
# Evaluate Result:
# Epoch-017     8 Batches, Step    144, Testing Loss:  0.160577, Used Time:   0.2m, Remaining Time:   0.0m
# -------------------------------------------------------------------------------
# Best Metric: 0.16057684622248825
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0287, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0269, requires_grad=True)
# Evaluate Result:
# Epoch-018     8 Batches, Step    152, Testing Loss:  0.205037, Used Time:   0.2m, Remaining Time:   0.0m
# -------------------------------------------------------------------------------
# Best Metric: 0.16057684622248825
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0303, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0311, requires_grad=True)
# Evaluate Result:
# Epoch-019     8 Batches, Step    160, Testing Loss:  0.181757, Used Time:   0.2m, Remaining Time:   0.0m
# -------------------------------------------------------------------------------
# Best Metric: 0.16057684622248825
# ####################################################################################
# Final Best Metric: 0.16057684622248825
# Final metrics: 0.18175693
# Init GBDT2NN
# Init GBDT2NN succeed!
# Cuda is not available, automatically changed into cpu model
# The model is deepfm(fm+deep layers)
# Init fm part
# Init fm part succeed
# Init deep part
# Init deep part succeed
# Init succeed
# Init DeepGBM succeed!
# Alpha: Parameter containing:
# tensor(0., requires_grad=True)
# Beta: Parameter containing:
# tensor(0., requires_grad=True)
# Evaluate Result:
# Epoch-000     8 Batches, Step      8, Testing Loss: 29.950730, Used Time:   0.0m, Remaining Time:   0.2m
# -------------------------------------------------------------------------------
# Best Metric: 29.95072979829749
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0., requires_grad=True)
# Beta: Parameter containing:
# tensor(0., requires_grad=True)
# Evaluate Result:
# Epoch-001     8 Batches, Step     16, Testing Loss: 29.640526, Used Time:   0.0m, Remaining Time:   0.2m
# -------------------------------------------------------------------------------
# Best Metric: 29.640525506467235
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0067, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0068, requires_grad=True)
# Evaluate Result:
# Epoch-002     8 Batches, Step     24, Testing Loss:  7.003142, Used Time:   0.0m, Remaining Time:   0.2m
# -------------------------------------------------------------------------------
# Best Metric: 7.003141568631542
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0142, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0137, requires_grad=True)
# Evaluate Result:
# Epoch-003     8 Batches, Step     32, Testing Loss:  0.729531, Used Time:   0.0m, Remaining Time:   0.2m
# -------------------------------------------------------------------------------
# Best Metric: 0.7295305327493318
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0107, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0131, requires_grad=True)
# Evaluate Result:
# Epoch-004     8 Batches, Step     40, Testing Loss:  0.661777, Used Time:   0.1m, Remaining Time:   0.2m
# -------------------------------------------------------------------------------
# Best Metric: 0.6617773296881695
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0083, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0122, requires_grad=True)
# Evaluate Result:
# Epoch-005     8 Batches, Step     48, Testing Loss:  1.190814, Used Time:   0.1m, Remaining Time:   0.1m
# -------------------------------------------------------------------------------
# Best Metric: 0.6617773296881695
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0123, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0148, requires_grad=True)
# Evaluate Result:
# Epoch-006     8 Batches, Step     56, Testing Loss:  0.295268, Used Time:   0.1m, Remaining Time:   0.1m
# -------------------------------------------------------------------------------
# Best Metric: 0.2952680228924265
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0137, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0155, requires_grad=True)
# Evaluate Result:
# Epoch-007     8 Batches, Step     64, Testing Loss:  0.275522, Used Time:   0.1m, Remaining Time:   0.1m
# -------------------------------------------------------------------------------
# Best Metric: 0.27552233788431907
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0146, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0158, requires_grad=True)
# Evaluate Result:
# Epoch-008     8 Batches, Step     72, Testing Loss:  0.275879, Used Time:   0.1m, Remaining Time:   0.1m
# -------------------------------------------------------------------------------
# Best Metric: 0.27552233788431907
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0173, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0176, requires_grad=True)
# Evaluate Result:
# Epoch-009     8 Batches, Step     80, Testing Loss:  0.233974, Used Time:   0.1m, Remaining Time:   0.1m
# -------------------------------------------------------------------------------
# Best Metric: 0.23397368253493794
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0190, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0184, requires_grad=True)
# Evaluate Result:
# Epoch-010     8 Batches, Step     88, Testing Loss:  0.223133, Used Time:   0.1m, Remaining Time:   0.1m
# -------------------------------------------------------------------------------
# Best Metric: 0.22313255375745344
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0211, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0199, requires_grad=True)
# Evaluate Result:
# Epoch-011     8 Batches, Step     96, Testing Loss:  0.196418, Used Time:   0.1m, Remaining Time:   0.1m
# -------------------------------------------------------------------------------
# Best Metric: 0.1964184273870624
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0233, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0218, requires_grad=True)
# Evaluate Result:
# Epoch-012     8 Batches, Step    104, Testing Loss:  0.201211, Used Time:   0.1m, Remaining Time:   0.1m
# -------------------------------------------------------------------------------
# Best Metric: 0.1964184273870624
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0253, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0238, requires_grad=True)
# Evaluate Result:
# Epoch-013     8 Batches, Step    112, Testing Loss:  0.176529, Used Time:   0.1m, Remaining Time:   0.1m
# -------------------------------------------------------------------------------
# Best Metric: 0.1765293244804655
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0272, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0264, requires_grad=True)
# Evaluate Result:
# Epoch-014     8 Batches, Step    120, Testing Loss:  0.187634, Used Time:   0.2m, Remaining Time:   0.1m
# -------------------------------------------------------------------------------
# Best Metric: 0.1765293244804655
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0286, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0285, requires_grad=True)
# Evaluate Result:
# Epoch-015     8 Batches, Step    128, Testing Loss:  0.180288, Used Time:   0.2m, Remaining Time:   0.0m
# -------------------------------------------------------------------------------
# Best Metric: 0.1765293244804655
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0299, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0312, requires_grad=True)
# Evaluate Result:
# Epoch-016     8 Batches, Step    136, Testing Loss:  0.173734, Used Time:   0.2m, Remaining Time:   0.0m
# -------------------------------------------------------------------------------
# Best Metric: 0.17373432021360008
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0310, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0339, requires_grad=True)
# Evaluate Result:
# Epoch-017     8 Batches, Step    144, Testing Loss:  0.215935, Used Time:   0.2m, Remaining Time:   0.0m
# -------------------------------------------------------------------------------
# Best Metric: 0.17373432021360008
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0317, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0352, requires_grad=True)
# Evaluate Result:
# Epoch-018     8 Batches, Step    152, Testing Loss:  0.200097, Used Time:   0.2m, Remaining Time:   0.0m
# -------------------------------------------------------------------------------
# Best Metric: 0.17373432021360008
# ####################################################################################
# Alpha: Parameter containing:
# tensor(0.0322, requires_grad=True)
# Beta: Parameter containing:
# tensor(0.0363, requires_grad=True)
# Evaluate Result:
# Epoch-019     8 Batches, Step    160, Testing Loss:  0.182816, Used Time:   0.2m, Remaining Time:   0.0m
# -------------------------------------------------------------------------------
# Best Metric: 0.17373432021360008
# ####################################################################################
# Final Best Metric: 0.17373432021360008
# Final metrics: 0.18281555
